# %%
import sys
sys.path.append('..')  # 添加上级目录到搜索路径
from utils import *

# %%
average_rhoR_ER = np.loadtxt("./SIR_rho_vs_beta/SIR_rho_vs_beta_ER_DC_plus.dat")
average_rhoR_BA = np.loadtxt("./SIR_rho_vs_beta/SIR_rho_vs_beta_BA_DC_plus.dat")

# %%
fig, axs = plt.subplots(1, 2, figsize=(4, 1.75), constrained_layout=True)
ax = axs[0]
ax.plot(average_rhoR_ER[:, 0], average_rhoR_ER[:, 1], marker = 'o', markersize = 3.0, markerfacecolor="w", linewidth = 1.0, clip_on=False, label="$l=$ "+str(0))
ax.plot(average_rhoR_ER[:, 0], average_rhoR_ER[:, 2], marker = 's', markersize = 3.0, markerfacecolor="w", linewidth = 1.0, clip_on=False, label="$l=$ "+str(1))
ax.plot(average_rhoR_ER[:, 0], average_rhoR_ER[:, 3], marker = 'D', markersize = 3.0, markerfacecolor="w", linewidth = 1.0, clip_on=False, label="$l=$ "+str(2))
ax.plot(average_rhoR_ER[:, 0], average_rhoR_ER[:, 4], marker = 'v', markersize = 3.0, markerfacecolor="w", linewidth = 1.0, clip_on=False, label="$l=$ "+str(3))           
ax.set_xlim(0.0, 2.0)
ax.set_ylim(0.0, 1.0)
ax.set_xlabel(r"$\beta$")
ax.set_ylabel(r"$\rho_r^l$")
ax.legend(loc=0, edgecolor = "black", handlelength=1.0, fontsize=8, frameon=True, fancybox=False)
ax.set_title(r"\textbf{(a)} ER", loc='center', y=-0.55, fontsize=12)

ax = axs[1]
ax.plot(average_rhoR_BA[:, 0], average_rhoR_BA[:, 1], marker = 'o', markersize = 3.0, markerfacecolor="w", linewidth = 1.0, clip_on=False, label="$l=$ "+str(0))
ax.plot(average_rhoR_BA[:, 0], average_rhoR_BA[:, 2], marker = 's', markersize = 3.0, markerfacecolor="w", linewidth = 1.0, clip_on=False, label="$l=$ "+str(1))
ax.plot(average_rhoR_BA[:, 0], average_rhoR_BA[:, 3], marker = 'D', markersize = 3.0, markerfacecolor="w", linewidth = 1.0, clip_on=False, label="$l=$ "+str(2))
ax.plot(average_rhoR_BA[:, 0], average_rhoR_BA[:, 4], marker = 'v', markersize = 3.0, markerfacecolor="w", linewidth = 1.0, clip_on=False, label="$l=$ "+str(3))           
ax.set_xlim(0.0, 2.0)
ax.set_ylim(0.0, 1.0)
ax.set_xlabel(r"$\beta$")
ax.set_ylabel(r"$\rho_r^l$")
ax.set_title(r"\textbf{(b)} BA", loc='center', y=-0.55, fontsize=12)

plt.savefig("SIR_rho_vs_beta_ER_BA_DC_plus.pdf")
plt.show()
